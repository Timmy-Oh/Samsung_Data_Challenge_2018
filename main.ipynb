# %%
import pandas as pd
import numpy as np
import pickle as pkl
import tensorflow as tf
import os, sys, math
import config

tf.set_random_seed(seed=1991)
np.random.seed(seed=1991)
# Out:
# c:\users\timmy\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
raw_df = pd.read_csv('./data/dataset_kor/교통사망사고정보/Kor_Train_교통사망사고정보(12.1~17.6).csv', engine='python')
raw_df = raw_df[config.test_cols]

# %%
for key in config.kv_map.keys():
#    print(key)
    raw_df[key] = raw_df[key].apply(lambda x: config.kv_map[key][x])

# %%
config.keep_prop = 0.7
config.train_size = 20480
config.cate_len = len(config.cate_cols)
config.cont_len = len(config.cont_cols)
config.cate_lens = [len(config.kv_map[k]) for k in config.cate_cols]

# %%
train_df = raw_df[:config.train_size]
valid_df = raw_df[config.train_size:]

# %% [markdown]
# # split

# %%
train_df_cate = train_df.loc[:,config.cate_cols]
train_df_cont = train_df.loc[:,config.cont_cols]

# %%
valid_df_cate = valid_df.loc[:,config.cate_cols]
valid_df_cont = valid_df.loc[:,config.cont_cols]

# %%
np.random.seed(seed=910919)
config.vaild_drop_mask = np.random.rand(valid_df_cate.values.shape[0], valid_df_cate.values.shape[1])> (1- config.keep_prop)

# %%
np.random.seed(seed=3632)
config.vaild_test_drop_mask = np.random.rand(valid_df_cate.values.shape[0], valid_df_cate.values.shape[1])> (1- config.keep_prop)

# %% [markdown]
# # model

# %%
config.dir_ckpt = '.\\ckpt'
config.path_ckpt = os.path.join(config.dir_ckpt, 'best.ckpt')
config.l1_size = 32
config.out_size = sum(config.cate_lens)
config.epochs = 500
config.batch_size = 1024

train_step = math.ceil(len(train_df)/ config.batch_size)
valid_step = math.ceil(len(valid_df)/ config.batch_size)

os.makedirs(config.dir_ckpt , exist_ok=True)

# %%
def build_model(config):
    tf.reset_default_graph()
    inp_cate = tf.placeholder(dtype=tf.int32, shape=[None, config.cate_len], name='categorical_input_layer')
    inp_cont = tf.placeholder(dtype=tf.int32, shape=[None, config.cont_len], name='continuous_input_layer')
    inp_cate_y = tf.placeholder(dtype=tf.int32, shape=[None, config.cate_len], name='categorical_input_y_layer')
    inp_cont_y = tf.placeholder(dtype=tf.int32, shape=[None, config.cont_len], name='continuous_input_y_layer')

    cate_oh = [tf.one_hot(inp_cate[:, i], depth=config.cate_lens[i]) for i in range(len(config.cate_cols))]
    cate_oh_y = [tf.one_hot(inp_cate_y[:, i], depth=config.cate_lens[i]) for i in range(len(config.cate_cols))]

    concat_cate = tf.concat(cate_oh, axis=-1)
    concat_cate_y = tf.concat(cate_oh_y, axis=-1)

    l1 = tf.contrib.layers.fully_connected(concat_cate, config.l1_size)
    l2 = tf.contrib.layers.fully_connected(concat_cate, config.out_size, activation_fn = tf.nn.sigmoid)
    
    pred = l2

    loss_op = tf.losses.mean_squared_error(concat_cate_y, l2)
    optimizer = tf.train.AdamOptimizer()
    train_op = optimizer.minimize(loss_op)

    return loss_op, train_op, inp_cate, inp_cont, inp_cate_y, inp_cont_y, pred

# %%
mdl = build_model(config)

# %%
saver = tf.train.Saver(max_to_keep=5)
init = tf.global_variables_initializer()

# %%
def run_session(sess, max_step, datas, config, epoch, mode=1):
    total_loss = 0.0
    loss_op, train_op, inp_cate, inp_cont, inp_cate_y, inp_cont_y, pred = mdl

    #train
    if mode ==1:
        drop_mask = np.random.rand(datas[0].values.shape[0], datas[0].values.shape[1])> (1- config.keep_prop)
        droped_cate = datas[0].values * drop_mask
        
        for step in range(max_step):
            start_idx = step * config.batch_size
            loss_, _ = sess.run([loss_op, train_op], feed_dict = {inp_cate:droped_cate[start_idx:start_idx+config.batch_size], 
                                                                  inp_cont:datas[1].values[start_idx:start_idx+config.batch_size], 
                                                                  inp_cate_y:datas[0].values[start_idx:start_idx+config.batch_size]})
            
            total_loss += loss_
        total_loss /= max_step
        return total_loss 
    
    #validation
    elif mode == 2:
        droped_valid_cate = datas[0].values * config.vaild_drop_mask
        
        for step in range(max_step):
            start_idx = step * config.batch_size
            loss_ = sess.run(loss_op, feed_dict = {inp_cate:droped_valid_cate[start_idx:start_idx+config.batch_size], 
                                                   inp_cont:datas[1].values[start_idx:start_idx+config.batch_size], 
                                                   inp_cate_y:datas[0].values[start_idx:start_idx+config.batch_size]})
            
            total_loss += loss_
        total_loss /= max_step
        return total_loss 
    
    #valid_test
    elif mode == 3:
        droped_valid_cate = datas[0].values * config.vaild_test_drop_mask
        preds = []
        for step in range(max_step):
            start_idx = step * config.batch_size
            pred_ = sess.run(pred, feed_dict = {inp_cate:droped_valid_cate[start_idx:start_idx+config.batch_size], 
                                                inp_cont:datas[1].values[start_idx:start_idx+config.batch_size]})
            preds.append(pred_)
            
        return preds
    
    else:
        print('error')
        return None

# %%
# =======================================================================================
# run session
with tf.Session() as sess:
    tf.set_random_seed(seed=1991)
    np.random.seed(seed=1991)
    sess.run(init)
    min_val_loss = 9999
    
    for epoch in range(1, config.epochs+1):
        print("Epoch : {}".format(epoch), end='\t')
        
        #train
        trn_total_loss_ = run_session(sess, train_step, [train_df_cate, train_df_cont], config, epoch, mode=1)
        print("Train_loss : {:.6f}".format(trn_total_loss_), end = '\t')
        
        #valid
        val_total_loss_ = run_session(sess, valid_step, [valid_df_cate, valid_df_cont], config, epoch, mode=2)
        print("Valid_loss : {:.6f}".format(val_total_loss_), end = '\t')
        
        if val_total_loss_ < min_val_loss:
            saver.save(sess, config.path_ckpt)
            min_val_loss = val_total_loss_
            print("Saved")
        else:
            print("No Saved")
# Out:
# Epoch : 1	Train_loss : 0.227814	Valid_loss : 0.201575	Saved
# Epoch : 2	Train_loss : 0.180795	Valid_loss : 0.159486	Saved
# Epoch : 3	Train_loss : 0.143410	Valid_loss : 0.127049	Saved
# Epoch : 4	Train_loss : 0.115071	Valid_loss : 0.102857	Saved
# Epoch : 5	Train_loss : 0.094035	Valid_loss : 0.084999	Saved
# Epoch : 6	Train_loss : 0.078521	Valid_loss : 0.071767	Saved
# Epoch : 7	Train_loss : 0.066933	Valid_loss : 0.061840	Saved
# Epoch : 8	Train_loss : 0.058201	Valid_loss : 0.054271	Saved
# Epoch : 9	Train_loss : 0.051460	Valid_loss : 0.048399	Saved
# Epoch : 10	Train_loss : 0.046195	Valid_loss : 0.043761	Saved
# Epoch : 11	Train_loss : 0.042003	Valid_loss : 0.040034	Saved
# Epoch : 12	Train_loss : 0.038626	Valid_loss : 0.036993	Saved
# Epoch : 13	Train_loss : 0.035846	Valid_loss : 0.034475	Saved
# Epoch : 14	Train_loss : 0.033501	Valid_loss : 0.032362	Saved
# Epoch : 15	Train_loss : 0.031560	Valid_loss : 0.030566	Saved
# Epoch : 16	Train_loss : 0.029872	Valid_loss : 0.029024	Saved
# Epoch : 17	Train_loss : 0.028434	Valid_loss : 0.027686	Saved
# Epoch : 18	Train_loss : 0.027150	Valid_loss : 0.026514	Saved
# Epoch : 19	Train_loss : 0.026057	Valid_loss : 0.025480	Saved
# Epoch : 20	Train_loss : 0.025079	Valid_loss : 0.024559	Saved
# Epoch : 21	Train_loss : 0.024188	Valid_loss : 0.023732	Saved
# Epoch : 22	Train_loss : 0.023384	Valid_loss : 0.022986	Saved
# Epoch : 23	Train_loss : 0.022688	Valid_loss : 0.022309	Saved
# Epoch : 24	Train_loss : 0.022043	Valid_loss : 0.021691	Saved
# Epoch : 25	Train_loss : 0.021434	Valid_loss : 0.021123	Saved
# Epoch : 26	Train_loss : 0.020857	Valid_loss : 0.020599	Saved
# Epoch : 27	Train_loss : 0.020370	Valid_loss : 0.020114	Saved
# Epoch : 28	Train_loss : 0.019920	Valid_loss : 0.019663	Saved
# Epoch : 29	Train_loss : 0.019431	Valid_loss : 0.019241	Saved
# Epoch : 30	Train_loss : 0.019046	Valid_loss : 0.018846	Saved
# Epoch : 31	Train_loss : 0.018657	Valid_loss : 0.018475	Saved
# Epoch : 32	Train_loss : 0.018299	Valid_loss : 0.018126	Saved
# Epoch : 33	Train_loss : 0.017947	Valid_loss : 0.017795	Saved
# Epoch : 34	Train_loss : 0.017649	Valid_loss : 0.017483	Saved
# Epoch : 35	Train_loss : 0.017330	Valid_loss : 0.017186	Saved
# Epoch : 36	Train_loss : 0.017003	Valid_loss : 0.016903	Saved
# Epoch : 37	Train_loss : 0.016760	Valid_loss : 0.016633	Saved
# Epoch : 38	Train_loss : 0.016494	Valid_loss : 0.016376	Saved
# Epoch : 39	Train_loss : 0.016233	Valid_loss : 0.016130	Saved
# Epoch : 40	Train_loss : 0.015955	Valid_loss : 0.015894	Saved
# Epoch : 41	Train_loss : 0.015735	Valid_loss : 0.015666	Saved
# Epoch : 42	Train_loss : 0.015511	Valid_loss : 0.015448	Saved
# Epoch : 43	Train_loss : 0.015312	Valid_loss : 0.015239	Saved
# Epoch : 44	Train_loss : 0.015111	Valid_loss : 0.015037	Saved
# Epoch : 45	Train_loss : 0.014888	Valid_loss : 0.014842	Saved
# Epoch : 46	Train_loss : 0.014711	Valid_loss : 0.014653	Saved
# Epoch : 47	Train_loss : 0.014502	Valid_loss : 0.014472	Saved
# Epoch : 48	Train_loss : 0.014352	Valid_loss : 0.014295	Saved
# Epoch : 49	Train_loss : 0.014147	Valid_loss : 0.014124	Saved
# Epoch : 50	Train_loss : 0.014025	Valid_loss : 0.013959	Saved
# Epoch : 51	Train_loss : 0.013817	Valid_loss : 0.013798	Saved
# Epoch : 52	Train_loss : 0.013650	Valid_loss : 0.013642	Saved
# Epoch : 53	Train_loss : 0.013505	Valid_loss : 0.013489	Saved
# Epoch : 54	Train_loss : 0.013349	Valid_loss : 0.013342	Saved
# Epoch : 55	Train_loss : 0.013216	Valid_loss : 0.013198	Saved
# Epoch : 56	Train_loss : 0.013068	Valid_loss : 0.013059	Saved
# Epoch : 57	Train_loss : 0.012923	Valid_loss : 0.012923	Saved
# Epoch : 58	Train_loss : 0.012786	Valid_loss : 0.012790	Saved
# Epoch : 59	Train_loss : 0.012659	Valid_loss : 0.012660	Saved
# Epoch : 60	Train_loss : 0.012527	Valid_loss : 0.012534	Saved
# Epoch : 61	Train_loss : 0.012426	Valid_loss : 0.012411	Saved
# Epoch : 62	Train_loss : 0.012264	Valid_loss : 0.012290	Saved
# Epoch : 63	Train_loss : 0.012160	Valid_loss : 0.012173	Saved
# Epoch : 64	Train_loss : 0.012015	Valid_loss : 0.012059	Saved
# Epoch : 65	Train_loss : 0.011928	Valid_loss : 0.011945	Saved
# Epoch : 66	Train_loss : 0.011807	Valid_loss : 0.011835	Saved
# Epoch : 67	Train_loss : 0.011699	Valid_loss : 0.011727	Saved
# Epoch : 68	Train_loss : 0.011621	Valid_loss : 0.011622	Saved
# Epoch : 69	Train_loss : 0.011475	Valid_loss : 0.011519	Saved
# Epoch : 70	Train_loss : 0.011427	Valid_loss : 0.011418	Saved
# Epoch : 71	Train_loss : 0.011281	Valid_loss : 0.011319	Saved
# Epoch : 72	Train_loss : 0.011216	Valid_loss : 0.011223	Saved
# Epoch : 73	Train_loss : 0.011082	Valid_loss : 0.011128	Saved
# Epoch : 74	Train_loss : 0.011010	Valid_loss : 0.011035	Saved
# Epoch : 75	Train_loss : 0.010914	Valid_loss : 0.010943	Saved
# Epoch : 76	Train_loss : 0.010812	Valid_loss : 0.010854	Saved
# Epoch : 77	Train_loss : 0.010759	Valid_loss : 0.010766	Saved
# Epoch : 78	Train_loss : 0.010658	Valid_loss : 0.010679	Saved
# Epoch : 79	Train_loss : 0.010543	Valid_loss : 0.010594	Saved
# Epoch : 80	Train_loss : 0.010499	Valid_loss : 0.010512	Saved
# Epoch : 81	Train_loss : 0.010369	Valid_loss : 0.010429	Saved
# Epoch : 82	Train_loss : 0.010298	Valid_loss : 0.010349	Saved
# Epoch : 83	Train_loss : 0.010235	Valid_loss : 0.010270	Saved
# Epoch : 84	Train_loss : 0.010174	Valid_loss : 0.010193	Saved
# Epoch : 85	Train_loss : 0.010076	Valid_loss : 0.010118	Saved
# Epoch : 86	Train_loss : 0.009997	Valid_loss : 0.010043	Saved
# Epoch : 87	Train_loss : 0.009894	Valid_loss : 0.009969	Saved
# Epoch : 88	Train_loss : 0.009850	Valid_loss : 0.009896	Saved
# Epoch : 89	Train_loss : 0.009783	Valid_loss : 0.009825	Saved
# Epoch : 90	Train_loss : 0.009682	Valid_loss : 0.009755	Saved
# Epoch : 91	Train_loss : 0.009635	Valid_loss : 0.009685	Saved
# Epoch : 92	Train_loss : 0.009561	Valid_loss : 0.009618	Saved
# Epoch : 93	Train_loss : 0.009499	Valid_loss : 0.009551	Saved
# Epoch : 94	Train_loss : 0.009420	Valid_loss : 0.009484	Saved
# Epoch : 95	Train_loss : 0.009387	Valid_loss : 0.009420	Saved
# Epoch : 96	Train_loss : 0.009338	Valid_loss : 0.009356	Saved
# Epoch : 97	Train_loss : 0.009253	Valid_loss : 0.009294	Saved
# Epoch : 98	Train_loss : 0.009180	Valid_loss : 0.009232	Saved
# Epoch : 99	Train_loss : 0.009138	Valid_loss : 0.009171	Saved
# Epoch : 100	Train_loss : 0.009028	Valid_loss : 0.009110	Saved
# Epoch : 101	Train_loss : 0.009015	Valid_loss : 0.009051	Saved
# Epoch : 102	Train_loss : 0.008901	Valid_loss : 0.008992	Saved
# Epoch : 103	Train_loss : 0.008866	Valid_loss : 0.008934	Saved
# Epoch : 104	Train_loss : 0.008833	Valid_loss : 0.008878	Saved
# Epoch : 105	Train_loss : 0.008755	Valid_loss : 0.008822	Saved
# Epoch : 106	Train_loss : 0.008685	Valid_loss : 0.008766	Saved
# Epoch : 107	Train_loss : 0.008679	Valid_loss : 0.008712	Saved
# Epoch : 108	Train_loss : 0.008592	Valid_loss : 0.008658	Saved
# Epoch : 109	Train_loss : 0.008569	Valid_loss : 0.008606	Saved
# Epoch : 110	Train_loss : 0.008522	Valid_loss : 0.008554	Saved
# Epoch : 111	Train_loss : 0.008448	Valid_loss : 0.008502	Saved
# Epoch : 112	Train_loss : 0.008417	Valid_loss : 0.008452	Saved
# Epoch : 113	Train_loss : 0.008327	Valid_loss : 0.008402	Saved
# Epoch : 114	Train_loss : 0.008322	Valid_loss : 0.008353	Saved
# Epoch : 115	Train_loss : 0.008245	Valid_loss : 0.008304	Saved
# Epoch : 116	Train_loss : 0.008211	Valid_loss : 0.008256	Saved
# Epoch : 117	Train_loss : 0.008136	Valid_loss : 0.008208	Saved
# Epoch : 118	Train_loss : 0.008104	Valid_loss : 0.008163	Saved
# Epoch : 119	Train_loss : 0.008090	Valid_loss : 0.008117	Saved
# Epoch : 120	Train_loss : 0.007983	Valid_loss : 0.008072	Saved
# Epoch : 121	Train_loss : 0.007967	Valid_loss : 0.008026	Saved
# Epoch : 122	Train_loss : 0.007886	Valid_loss : 0.007982	Saved
# Epoch : 123	Train_loss : 0.007887	Valid_loss : 0.007939	Saved
# Epoch : 124	Train_loss : 0.007795	Valid_loss : 0.007896	Saved
# Epoch : 125	Train_loss : 0.007811	Valid_loss : 0.007853	Saved
# Epoch : 126	Train_loss : 0.007759	Valid_loss : 0.007811	Saved
# Epoch : 127	Train_loss : 0.007734	Valid_loss : 0.007770	Saved
# Epoch : 128	Train_loss : 0.007662	Valid_loss : 0.007729	Saved
# Epoch : 129	Train_loss : 0.007660	Valid_loss : 0.007689	Saved
# Epoch : 130	Train_loss : 0.007627	Valid_loss : 0.007650	Saved
# Epoch : 131	Train_loss : 0.007568	Valid_loss : 0.007610	Saved
# Epoch : 132	Train_loss : 0.007541	Valid_loss : 0.007573	Saved
# Epoch : 133	Train_loss : 0.007452	Valid_loss : 0.007534	Saved
# Epoch : 134	Train_loss : 0.007467	Valid_loss : 0.007497	Saved
# Epoch : 135	Train_loss : 0.007357	Valid_loss : 0.007460	Saved
# Epoch : 136	Train_loss : 0.007375	Valid_loss : 0.007423	Saved
# Epoch : 137	Train_loss : 0.007311	Valid_loss : 0.007387	Saved
# Epoch : 138	Train_loss : 0.007275	Valid_loss : 0.007352	Saved
# Epoch : 139	Train_loss : 0.007279	Valid_loss : 0.007318	Saved
# Epoch : 140	Train_loss : 0.007236	Valid_loss : 0.007283	Saved
# Epoch : 141	Train_loss : 0.007149	Valid_loss : 0.007248	Saved
# Epoch : 142	Train_loss : 0.007163	Valid_loss : 0.007214	Saved
# Epoch : 143	Train_loss : 0.007135	Valid_loss : 0.007181	Saved
# Epoch : 144	Train_loss : 0.007102	Valid_loss : 0.007149	Saved
# Epoch : 145	Train_loss : 0.007045	Valid_loss : 0.007117	Saved
# Epoch : 146	Train_loss : 0.007046	Valid_loss : 0.007085	Saved
# Epoch : 147	Train_loss : 0.007003	Valid_loss : 0.007052	Saved
# Epoch : 148	Train_loss : 0.006971	Valid_loss : 0.007022	Saved
# Epoch : 149	Train_loss : 0.006961	Valid_loss : 0.006993	Saved
# Epoch : 150	Train_loss : 0.006933	Valid_loss : 0.006962	Saved
# Epoch : 151	Train_loss : 0.006865	Valid_loss : 0.006932	Saved
# Epoch : 152	Train_loss : 0.006846	Valid_loss : 0.006902	Saved
# Epoch : 153	Train_loss : 0.006837	Valid_loss : 0.006873	Saved
# Epoch : 154	Train_loss : 0.006781	Valid_loss : 0.006846	Saved
# Epoch : 155	Train_loss : 0.006769	Valid_loss : 0.006817	Saved
# Epoch : 156	Train_loss : 0.006746	Valid_loss : 0.006789	Saved
# Epoch : 157	Train_loss : 0.006734	Valid_loss : 0.006762	Saved
# Epoch : 158	Train_loss : 0.006674	Valid_loss : 0.006735	Saved
# Epoch : 159	Train_loss : 0.006654	Valid_loss : 0.006707	Saved
# Epoch : 160	Train_loss : 0.006607	Valid_loss : 0.006680	Saved
# Epoch : 161	Train_loss : 0.006595	Valid_loss : 0.006655	Saved
# Epoch : 162	Train_loss : 0.006604	Valid_loss : 0.006629	Saved
# Epoch : 163	Train_loss : 0.006505	Valid_loss : 0.006604	Saved
# Epoch : 164	Train_loss : 0.006511	Valid_loss : 0.006579	Saved
# Epoch : 165	Train_loss : 0.006468	Valid_loss : 0.006553	Saved
# Epoch : 166	Train_loss : 0.006476	Valid_loss : 0.006528	Saved
# Epoch : 167	Train_loss : 0.006442	Valid_loss : 0.006505	Saved
# Epoch : 168	Train_loss : 0.006427	Valid_loss : 0.006481	Saved
# Epoch : 169	Train_loss : 0.006417	Valid_loss : 0.006458	Saved
# Epoch : 170	Train_loss : 0.006361	Valid_loss : 0.006434	Saved
# Epoch : 171	Train_loss : 0.006344	Valid_loss : 0.006411	Saved
# Epoch : 172	Train_loss : 0.006345	Valid_loss : 0.006390	Saved
# Epoch : 173	Train_loss : 0.006291	Valid_loss : 0.006367	Saved
# Epoch : 174	Train_loss : 0.006265	Valid_loss : 0.006344	Saved
# Epoch : 175	Train_loss : 0.006269	Valid_loss : 0.006322	Saved
# Epoch : 176	Train_loss : 0.006257	Valid_loss : 0.006302	Saved
# Epoch : 177	Train_loss : 0.006233	Valid_loss : 0.006281	Saved
# Epoch : 178	Train_loss : 0.006232	Valid_loss : 0.006260	Saved
# Epoch : 179	Train_loss : 0.006168	Valid_loss : 0.006239	Saved
# Epoch : 180	Train_loss : 0.006135	Valid_loss : 0.006218	Saved
# Epoch : 181	Train_loss : 0.006159	Valid_loss : 0.006197	Saved
# Epoch : 182	Train_loss : 0.006112	Valid_loss : 0.006178	Saved
# Epoch : 183	Train_loss : 0.006101	Valid_loss : 0.006158	Saved
# Epoch : 184	Train_loss : 0.006073	Valid_loss : 0.006138	Saved
# Epoch : 185	Train_loss : 0.006044	Valid_loss : 0.006120	Saved
# Epoch : 186	Train_loss : 0.006074	Valid_loss : 0.006101	Saved
# Epoch : 187	Train_loss : 0.006028	Valid_loss : 0.006082	Saved
# Epoch : 188	Train_loss : 0.006031	Valid_loss : 0.006064	Saved
# Epoch : 189	Train_loss : 0.006016	Valid_loss : 0.006045	Saved
# Epoch : 190	Train_loss : 0.006002	Valid_loss : 0.006027	Saved
# Epoch : 191	Train_loss : 0.005966	Valid_loss : 0.006009	Saved
# Epoch : 192	Train_loss : 0.005962	Valid_loss : 0.005991	Saved
# Epoch : 193	Train_loss : 0.005926	Valid_loss : 0.005974	Saved
# Epoch : 194	Train_loss : 0.005884	Valid_loss : 0.005957	Saved
# Epoch : 195	Train_loss : 0.005944	Valid_loss : 0.005940	Saved
# Epoch : 196	Train_loss : 0.005887	Valid_loss : 0.005924	Saved
# Epoch : 197	Train_loss : 0.005864	Valid_loss : 0.005907	Saved
# Epoch : 198	Train_loss : 0.005837	Valid_loss : 0.005891	Saved
# Epoch : 199	Train_loss : 0.005850	Valid_loss : 0.005875	Saved
# Epoch : 200	Train_loss : 0.005820	Valid_loss : 0.005859	Saved
# Epoch : 201	Train_loss : 0.005810	Valid_loss : 0.005844	Saved
# Epoch : 202	Train_loss : 0.005798	Valid_loss : 0.005828	Saved
# Epoch : 203	Train_loss : 0.005790	Valid_loss : 0.005813	Saved
# Epoch : 204	Train_loss : 0.005760	Valid_loss : 0.005797	Saved
# Epoch : 205	Train_loss : 0.005739	Valid_loss : 0.005781	Saved
# Epoch : 206	Train_loss : 0.005727	Valid_loss : 0.005767	Saved
# Epoch : 207	Train_loss : 0.005736	Valid_loss : 0.005753	Saved
# Epoch : 208	Train_loss : 0.005714	Valid_loss : 0.005739	Saved
# Epoch : 209	Train_loss : 0.005698	Valid_loss : 0.005724	Saved
# Epoch : 210	Train_loss : 0.005660	Valid_loss : 0.005710	Saved
# Epoch : 211	Train_loss : 0.005688	Valid_loss : 0.005697	Saved
# Epoch : 212	Train_loss : 0.005632	Valid_loss : 0.005683	Saved
# Epoch : 213	Train_loss : 0.005633	Valid_loss : 0.005668	Saved
# Epoch : 214	Train_loss : 0.005606	Valid_loss : 0.005656	Saved
# Epoch : 215	Train_loss : 0.005614	Valid_loss : 0.005643	Saved
# Epoch : 216	Train_loss : 0.005588	Valid_loss : 0.005629	Saved
# Epoch : 217	Train_loss : 0.005637	Valid_loss : 0.005617	Saved
# Epoch : 218	Train_loss : 0.005564	Valid_loss : 0.005603	Saved
# Epoch : 219	Train_loss : 0.005582	Valid_loss : 0.005591	Saved
# Epoch : 220	Train_loss : 0.005543	Valid_loss : 0.005578	Saved
# Epoch : 221	Train_loss : 0.005555	Valid_loss : 0.005566	Saved
# Epoch : 222	Train_loss : 0.005497	Valid_loss : 0.005554	Saved
# Epoch : 223	Train_loss : 0.005497	Valid_loss : 0.005541	Saved
# Epoch : 224	Train_loss : 0.005500	Valid_loss : 0.005530	Saved
# Epoch : 225	Train_loss : 0.005513	Valid_loss : 0.005518	Saved
# Epoch : 226	Train_loss : 0.005461	Valid_loss : 0.005506	Saved
# Epoch : 227	Train_loss : 0.005440	Valid_loss : 0.005495	Saved
# Epoch : 228	Train_loss : 0.005454	Valid_loss : 0.005484	Saved
# Epoch : 229	Train_loss : 0.005391	Valid_loss : 0.005472	Saved
# Epoch : 230	Train_loss : 0.005428	Valid_loss : 0.005460	Saved
# Epoch : 231	Train_loss : 0.005405	Valid_loss : 0.005450	Saved
# Epoch : 232	Train_loss : 0.005355	Valid_loss : 0.005439	Saved
# Epoch : 233	Train_loss : 0.005365	Valid_loss : 0.005428	Saved
# Epoch : 234	Train_loss : 0.005393	Valid_loss : 0.005419	Saved
# Epoch : 235	Train_loss : 0.005360	Valid_loss : 0.005408	Saved
# Epoch : 236	Train_loss : 0.005342	Valid_loss : 0.005398	Saved
# Epoch : 237	Train_loss : 0.005349	Valid_loss : 0.005387	Saved
# Epoch : 238	Train_loss : 0.005329	Valid_loss : 0.005377	Saved
# Epoch : 239	Train_loss : 0.005316	Valid_loss : 0.005366	Saved
# Epoch : 240	Train_loss : 0.005348	Valid_loss : 0.005356	Saved
# Epoch : 241	Train_loss : 0.005329	Valid_loss : 0.005346	Saved
# Epoch : 242	Train_loss : 0.005277	Valid_loss : 0.005336	Saved
# Epoch : 243	Train_loss : 0.005255	Valid_loss : 0.005327	Saved
# Epoch : 244	Train_loss : 0.005272	Valid_loss : 0.005316	Saved
# Epoch : 245	Train_loss : 0.005273	Valid_loss : 0.005306	Saved
# Epoch : 246	Train_loss : 0.005299	Valid_loss : 0.005297	Saved
# Epoch : 247	Train_loss : 0.005227	Valid_loss : 0.005289	Saved
# Epoch : 248	Train_loss : 0.005247	Valid_loss : 0.005280	Saved
# Epoch : 249	Train_loss : 0.005222	Valid_loss : 0.005271	Saved
# Epoch : 250	Train_loss : 0.005214	Valid_loss : 0.005263	Saved
# Epoch : 251	Train_loss : 0.005189	Valid_loss : 0.005253	Saved
# Epoch : 252	Train_loss : 0.005201	Valid_loss : 0.005245	Saved
# Epoch : 253	Train_loss : 0.005201	Valid_loss : 0.005235	Saved
# Epoch : 254	Train_loss : 0.005197	Valid_loss : 0.005226	Saved
# Epoch : 255	Train_loss : 0.005157	Valid_loss : 0.005218	Saved
# Epoch : 256	Train_loss : 0.005172	Valid_loss : 0.005210	Saved
# Epoch : 257	Train_loss : 0.005153	Valid_loss : 0.005202	Saved
# Epoch : 258	Train_loss : 0.005181	Valid_loss : 0.005194	Saved
# Epoch : 259	Train_loss : 0.005162	Valid_loss : 0.005186	Saved
# Epoch : 260	Train_loss : 0.005151	Valid_loss : 0.005178	Saved
# Epoch : 261	Train_loss : 0.005137	Valid_loss : 0.005170	Saved
# Epoch : 262	Train_loss : 0.005128	Valid_loss : 0.005162	Saved
# Epoch : 263	Train_loss : 0.005115	Valid_loss : 0.005154	Saved
# Epoch : 264	Train_loss : 0.005131	Valid_loss : 0.005147	Saved
# Epoch : 265	Train_loss : 0.005104	Valid_loss : 0.005138	Saved
# Epoch : 266	Train_loss : 0.005061	Valid_loss : 0.005131	Saved
# Epoch : 267	Train_loss : 0.005129	Valid_loss : 0.005124	Saved
# Epoch : 268	Train_loss : 0.005102	Valid_loss : 0.005116	Saved
# Epoch : 269	Train_loss : 0.005062	Valid_loss : 0.005110	Saved
# Epoch : 270	Train_loss : 0.005074	Valid_loss : 0.005103	Saved
# Epoch : 271	Train_loss : 0.005036	Valid_loss : 0.005096	Saved
# Epoch : 272	Train_loss : 0.005071	Valid_loss : 0.005088	Saved
# Epoch : 273	Train_loss : 0.005005	Valid_loss : 0.005081	Saved
# Epoch : 274	Train_loss : 0.005025	Valid_loss : 0.005074	Saved
# Epoch : 275	Train_loss : 0.005018	Valid_loss : 0.005068	Saved
# Epoch : 276	Train_loss : 0.005044	Valid_loss : 0.005061	Saved
# Epoch : 277	Train_loss : 0.004991	Valid_loss : 0.005055	Saved
# Epoch : 278	Train_loss : 0.005027	Valid_loss : 0.005048	Saved
# Epoch : 279	Train_loss : 0.005009	Valid_loss : 0.005042	Saved
# Epoch : 280	Train_loss : 0.005027	Valid_loss : 0.005034	Saved
# Epoch : 281	Train_loss : 0.004996	Valid_loss : 0.005028	Saved
# Epoch : 282	Train_loss : 0.004959	Valid_loss : 0.005022	Saved
# Epoch : 283	Train_loss : 0.005021	Valid_loss : 0.005015	Saved
# Epoch : 284	Train_loss : 0.004972	Valid_loss : 0.005009	Saved
# Epoch : 285	Train_loss : 0.004969	Valid_loss : 0.005004	Saved
# Epoch : 286	Train_loss : 0.004937	Valid_loss : 0.004997	Saved
# Epoch : 287	Train_loss : 0.004977	Valid_loss : 0.004990	Saved
# Epoch : 288	Train_loss : 0.004990	Valid_loss : 0.004985	Saved
# Epoch : 289	Train_loss : 0.004976	Valid_loss : 0.004980	Saved
# Epoch : 290	Train_loss : 0.004972	Valid_loss : 0.004973	Saved
# Epoch : 291	Train_loss : 0.004886	Valid_loss : 0.004967	Saved
# Epoch : 292	Train_loss : 0.004949	Valid_loss : 0.004962	Saved
# Epoch : 293	Train_loss : 0.004907	Valid_loss : 0.004956	Saved
# Epoch : 294	Train_loss : 0.004869	Valid_loss : 0.004950	Saved
# Epoch : 295	Train_loss : 0.004904	Valid_loss : 0.004945	Saved
# Epoch : 296	Train_loss : 0.004927	Valid_loss : 0.004939	Saved
# Epoch : 297	Train_loss : 0.004837	Valid_loss : 0.004933	Saved
# Epoch : 298	Train_loss : 0.004890	Valid_loss : 0.004928	Saved
# Epoch : 299	Train_loss : 0.004846	Valid_loss : 0.004923	Saved
# Epoch : 300	Train_loss : 0.004893	Valid_loss : 0.004918	Saved
# Epoch : 301	Train_loss : 0.004891	Valid_loss : 0.004911	Saved
# Epoch : 302	Train_loss : 0.004847	Valid_loss : 0.004907	Saved
# Epoch : 303	Train_loss : 0.004873	Valid_loss : 0.004904	Saved
# Epoch : 304	Train_loss : 0.004851	Valid_loss : 0.004897	Saved
# Epoch : 305	Train_loss : 0.004847	Valid_loss : 0.004892	Saved
# Epoch : 306	Train_loss : 0.004875	Valid_loss : 0.004888	Saved
# Epoch : 307	Train_loss : 0.004889	Valid_loss : 0.004883	Saved
# Epoch : 308	Train_loss : 0.004840	Valid_loss : 0.004879	Saved
# Epoch : 309	Train_loss : 0.004845	Valid_loss : 0.004873	Saved
# Epoch : 310	Train_loss : 0.004833	Valid_loss : 0.004868	Saved
# Epoch : 311	Train_loss : 0.004842	Valid_loss : 0.004864	Saved
# Epoch : 312	Train_loss : 0.004821	Valid_loss : 0.004859	Saved
# Epoch : 313	Train_loss : 0.004794	Valid_loss : 0.004854	Saved
# Epoch : 314	Train_loss : 0.004806	Valid_loss : 0.004851	Saved
# Epoch : 315	Train_loss : 0.004824	Valid_loss : 0.004846	Saved
# Epoch : 316	Train_loss : 0.004780	Valid_loss : 0.004840	Saved
# Epoch : 317	Train_loss : 0.004797	Valid_loss : 0.004836	Saved
# Epoch : 318	Train_loss : 0.004805	Valid_loss : 0.004832	Saved
# Epoch : 319	Train_loss : 0.004809	Valid_loss : 0.004828	Saved
# Epoch : 320	Train_loss : 0.004804	Valid_loss : 0.004824	Saved
# Epoch : 321	Train_loss : 0.004799	Valid_loss : 0.004821	Saved
# Epoch : 322	Train_loss : 0.004731	Valid_loss : 0.004816	Saved
# Epoch : 323	Train_loss : 0.004768	Valid_loss : 0.004812	Saved
# Epoch : 324	Train_loss : 0.004766	Valid_loss : 0.004808	Saved
# Epoch : 325	Train_loss : 0.004778	Valid_loss : 0.004804	Saved
# Epoch : 326	Train_loss : 0.004749	Valid_loss : 0.004800	Saved
# Epoch : 327	Train_loss : 0.004749	Valid_loss : 0.004795	Saved
# Epoch : 328	Train_loss : 0.004747	Valid_loss : 0.004791	Saved
# Epoch : 329	Train_loss : 0.004745	Valid_loss : 0.004788	Saved
# Epoch : 330	Train_loss : 0.004777	Valid_loss : 0.004784	Saved
# Epoch : 331	Train_loss : 0.004739	Valid_loss : 0.004781	Saved
# Epoch : 332	Train_loss : 0.004785	Valid_loss : 0.004776	Saved
# Epoch : 333	Train_loss : 0.004729	Valid_loss : 0.004772	Saved
# Epoch : 334	Train_loss : 0.004764	Valid_loss : 0.004768	Saved
# Epoch : 335	Train_loss : 0.004733	Valid_loss : 0.004765	Saved
# Epoch : 336	Train_loss : 0.004740	Valid_loss : 0.004762	Saved
# Epoch : 337	Train_loss : 0.004681	Valid_loss : 0.004758	Saved
# Epoch : 338	Train_loss : 0.004738	Valid_loss : 0.004754	Saved
# Epoch : 339	Train_loss : 0.004718	Valid_loss : 0.004750	Saved
# Epoch : 340	Train_loss : 0.004709	Valid_loss : 0.004746	Saved
# Epoch : 341	Train_loss : 0.004664	Valid_loss : 0.004742	Saved
# Epoch : 342	Train_loss : 0.004673	Valid_loss : 0.004738	Saved
# Epoch : 343	Train_loss : 0.004680	Valid_loss : 0.004736	Saved
# Epoch : 344	Train_loss : 0.004753	Valid_loss : 0.004734	Saved
# Epoch : 345	Train_loss : 0.004698	Valid_loss : 0.004731	Saved
# Epoch : 346	Train_loss : 0.004660	Valid_loss : 0.004727	Saved
# Epoch : 347	Train_loss : 0.004664	Valid_loss : 0.004722	Saved
# Epoch : 348	Train_loss : 0.004644	Valid_loss : 0.004719	Saved
# Epoch : 349	Train_loss : 0.004678	Valid_loss : 0.004716	Saved
# Epoch : 350	Train_loss : 0.004674	Valid_loss : 0.004713	Saved
# Epoch : 351	Train_loss : 0.004655	Valid_loss : 0.004710	Saved
# Epoch : 352	Train_loss : 0.004681	Valid_loss : 0.004707	Saved
# Epoch : 353	Train_loss : 0.004652	Valid_loss : 0.004705	Saved
# Epoch : 354	Train_loss : 0.004653	Valid_loss : 0.004700	Saved
# Epoch : 355	Train_loss : 0.004678	Valid_loss : 0.004697	Saved
# Epoch : 356	Train_loss : 0.004670	Valid_loss : 0.004694	Saved
# Epoch : 357	Train_loss : 0.004645	Valid_loss : 0.004691	Saved
# Epoch : 358	Train_loss : 0.004670	Valid_loss : 0.004688	Saved
# Epoch : 359	Train_loss : 0.004681	Valid_loss : 0.004685	Saved
# Epoch : 360	Train_loss : 0.004673	Valid_loss : 0.004682	Saved
# Epoch : 361	Train_loss : 0.004671	Valid_loss : 0.004679	Saved
# Epoch : 362	Train_loss : 0.004603	Valid_loss : 0.004677	Saved
# Epoch : 363	Train_loss : 0.004659	Valid_loss : 0.004675	Saved
# Epoch : 364	Train_loss : 0.004634	Valid_loss : 0.004672	Saved
# Epoch : 365	Train_loss : 0.004647	Valid_loss : 0.004668	Saved
# Epoch : 366	Train_loss : 0.004658	Valid_loss : 0.004665	Saved
# Epoch : 367	Train_loss : 0.004588	Valid_loss : 0.004662	Saved
# Epoch : 368	Train_loss : 0.004661	Valid_loss : 0.004659	Saved
# Epoch : 369	Train_loss : 0.004624	Valid_loss : 0.004656	Saved
# Epoch : 370	Train_loss : 0.004607	Valid_loss : 0.004654	Saved
# Epoch : 371	Train_loss : 0.004596	Valid_loss : 0.004652	Saved
# Epoch : 372	Train_loss : 0.004615	Valid_loss : 0.004649	Saved
# Epoch : 373	Train_loss : 0.004621	Valid_loss : 0.004646	Saved
# Epoch : 374	Train_loss : 0.004570	Valid_loss : 0.004644	Saved
# Epoch : 375	Train_loss : 0.004576	Valid_loss : 0.004642	Saved
# Epoch : 376	Train_loss : 0.004613	Valid_loss : 0.004640	Saved
# Epoch : 377	Train_loss : 0.004598	Valid_loss : 0.004637	Saved
# Epoch : 378	Train_loss : 0.004588	Valid_loss : 0.004635	Saved
# Epoch : 379	Train_loss : 0.004626	Valid_loss : 0.004632	Saved
# Epoch : 380	Train_loss : 0.004595	Valid_loss : 0.004629	Saved
# Epoch : 381	Train_loss : 0.004609	Valid_loss : 0.004626	Saved
# Epoch : 382	Train_loss : 0.004573	Valid_loss : 0.004623	Saved
# Epoch : 383	Train_loss : 0.004588	Valid_loss : 0.004623	Saved
# Epoch : 384	Train_loss : 0.004598	Valid_loss : 0.004621	Saved
# Epoch : 385	Train_loss : 0.004589	Valid_loss : 0.004617	Saved
# Epoch : 386	Train_loss : 0.004550	Valid_loss : 0.004615	Saved
# Epoch : 387	Train_loss : 0.004579	Valid_loss : 0.004613	Saved
# Epoch : 388	Train_loss : 0.004551	Valid_loss : 0.004611	Saved
# Epoch : 389	Train_loss : 0.004555	Valid_loss : 0.004609	Saved
# Epoch : 390	Train_loss : 0.004561	Valid_loss : 0.004607	Saved
# Epoch : 391	Train_loss : 0.004532	Valid_loss : 0.004605	Saved
# Epoch : 392	Train_loss : 0.004570	Valid_loss : 0.004602	Saved
# Epoch : 393	Train_loss : 0.004583	Valid_loss : 0.004600	Saved
# Epoch : 394	Train_loss : 0.004569	Valid_loss : 0.004596	Saved
# Epoch : 395	Train_loss : 0.004540	Valid_loss : 0.004593	Saved
# Epoch : 396	Train_loss : 0.004531	Valid_loss : 0.004592	Saved
# Epoch : 397	Train_loss : 0.004566	Valid_loss : 0.004590	Saved
# Epoch : 398	Train_loss : 0.004550	Valid_loss : 0.004588	Saved
# Epoch : 399	Train_loss : 0.004571	Valid_loss : 0.004587	Saved
# Epoch : 400	Train_loss : 0.004550	Valid_loss : 0.004585	Saved
# Epoch : 401	Train_loss : 0.004596	Valid_loss : 0.004584	Saved
# Epoch : 402	Train_loss : 0.004553	Valid_loss : 0.004583	Saved
# Epoch : 403	Train_loss : 0.004561	Valid_loss : 0.004580	Saved
# Epoch : 404	Train_loss : 0.004517	Valid_loss : 0.004577	Saved
# Epoch : 405	Train_loss : 0.004522	Valid_loss : 0.004576	Saved
# Epoch : 406	Train_loss : 0.004560	Valid_loss : 0.004574	Saved
# Epoch : 407	Train_loss : 0.004513	Valid_loss : 0.004572	Saved
# Epoch : 408	Train_loss : 0.004555	Valid_loss : 0.004571	Saved
# Epoch : 409	Train_loss : 0.004490	Valid_loss : 0.004569	Saved
# Epoch : 410	Train_loss : 0.004504	Valid_loss : 0.004566	Saved
# Epoch : 411	Train_loss : 0.004484	Valid_loss : 0.004564	Saved
# Epoch : 412	Train_loss : 0.004560	Valid_loss : 0.004561	Saved
# Epoch : 413	Train_loss : 0.004546	Valid_loss : 0.004560	Saved
# Epoch : 414	Train_loss : 0.004518	Valid_loss : 0.004558	Saved
# Epoch : 415	Train_loss : 0.004519	Valid_loss : 0.004557	Saved
# Epoch : 416	Train_loss : 0.004508	Valid_loss : 0.004557	Saved
# Epoch : 417	Train_loss : 0.004481	Valid_loss : 0.004555	Saved
# Epoch : 418	Train_loss : 0.004540	Valid_loss : 0.004554	Saved
# Epoch : 419	Train_loss : 0.004512	Valid_loss : 0.004551	Saved
# Epoch : 420	Train_loss : 0.004562	Valid_loss : 0.004549	Saved
# Epoch : 421	Train_loss : 0.004515	Valid_loss : 0.004549	Saved
# Epoch : 422	Train_loss : 0.004489	Valid_loss : 0.004547	Saved
# Epoch : 423	Train_loss : 0.004475	Valid_loss : 0.004545	Saved
# Epoch : 424	Train_loss : 0.004513	Valid_loss : 0.004544	Saved
# Epoch : 425	Train_loss : 0.004481	Valid_loss : 0.004542	Saved
# Epoch : 426	Train_loss : 0.004509	Valid_loss : 0.004540	Saved
# Epoch : 427	Train_loss : 0.004505	Valid_loss : 0.004537	Saved
# Epoch : 428	Train_loss : 0.004508	Valid_loss : 0.004535	Saved
# Epoch : 429	Train_loss : 0.004501	Valid_loss : 0.004533	Saved
# Epoch : 430	Train_loss : 0.004487	Valid_loss : 0.004532	Saved
# Epoch : 431	Train_loss : 0.004546	Valid_loss : 0.004531	Saved
# Epoch : 432	Train_loss : 0.004485	Valid_loss : 0.004530	Saved
# Epoch : 433	Train_loss : 0.004467	Valid_loss : 0.004528	Saved
# Epoch : 434	Train_loss : 0.004488	Valid_loss : 0.004527	Saved
# Epoch : 435	Train_loss : 0.004464	Valid_loss : 0.004526	Saved
# Epoch : 436	Train_loss : 0.004473	Valid_loss : 0.004525	Saved
# Epoch : 437	Train_loss : 0.004510	Valid_loss : 0.004523	Saved
# Epoch : 438	Train_loss : 0.004532	Valid_loss : 0.004522	Saved
# Epoch : 439	Train_loss : 0.004487	Valid_loss : 0.004520	Saved
# Epoch : 440	Train_loss : 0.004501	Valid_loss : 0.004518	Saved
# Epoch : 441	Train_loss : 0.004483	Valid_loss : 0.004517	Saved
# Epoch : 442	Train_loss : 0.004504	Valid_loss : 0.004516	Saved
# Epoch : 443	Train_loss : 0.004480	Valid_loss : 0.004514	Saved
# Epoch : 444	Train_loss : 0.004474	Valid_loss : 0.004512	Saved
# Epoch : 445	Train_loss : 0.004469	Valid_loss : 0.004512	Saved
# Epoch : 446	Train_loss : 0.004469	Valid_loss : 0.004510	Saved
# Epoch : 447	Train_loss : 0.004483	Valid_loss : 0.004507	Saved
# Epoch : 448	Train_loss : 0.004465	Valid_loss : 0.004508	No Saved
# Epoch : 449	Train_loss : 0.004470	Valid_loss : 0.004506	Saved
# Epoch : 450	Train_loss : 0.004473	Valid_loss : 0.004504	Saved
# Epoch : 451	Train_loss : 0.004455	Valid_loss : 0.004504	Saved
# Epoch : 452	Train_loss : 0.004418	Valid_loss : 0.004503	Saved
# Epoch : 453	Train_loss : 0.004473	Valid_loss : 0.004502	Saved
# Epoch : 454	Train_loss : 0.004475	Valid_loss : 0.004500	Saved
# Epoch : 455	Train_loss : 0.004445	Valid_loss : 0.004499	Saved
# Epoch : 456	Train_loss : 0.004492	Valid_loss : 0.004496	Saved
# Epoch : 457	Train_loss : 0.004455	Valid_loss : 0.004496	Saved
# Epoch : 458	Train_loss : 0.004425	Valid_loss : 0.004496	Saved
# Epoch : 459	Train_loss : 0.004460	Valid_loss : 0.004494	Saved
# Epoch : 460	Train_loss : 0.004447	Valid_loss : 0.004493	Saved
# Epoch : 461	Train_loss : 0.004446	Valid_loss : 0.004492	Saved
# Epoch : 462	Train_loss : 0.004448	Valid_loss : 0.004491	Saved
# Epoch : 463	Train_loss : 0.004484	Valid_loss : 0.004489	Saved
# Epoch : 464	Train_loss : 0.004446	Valid_loss : 0.004487	Saved
# Epoch : 465	Train_loss : 0.004484	Valid_loss : 0.004486	Saved
# Epoch : 466	Train_loss : 0.004442	Valid_loss : 0.004486	Saved
# Epoch : 467	Train_loss : 0.004441	Valid_loss : 0.004484	Saved
# Epoch : 468	Train_loss : 0.004452	Valid_loss : 0.004483	Saved
# Epoch : 469	Train_loss : 0.004415	Valid_loss : 0.004482	Saved
# Epoch : 470	Train_loss : 0.004454	Valid_loss : 0.004481	Saved
# Epoch : 471	Train_loss : 0.004465	Valid_loss : 0.004479	Saved
# Epoch : 472	Train_loss : 0.004426	Valid_loss : 0.004478	Saved
# Epoch : 473	Train_loss : 0.004412	Valid_loss : 0.004477	Saved
# Epoch : 474	Train_loss : 0.004430	Valid_loss : 0.004476	Saved
# Epoch : 475	Train_loss : 0.004434	Valid_loss : 0.004475	Saved
# Epoch : 476	Train_loss : 0.004443	Valid_loss : 0.004474	Saved
# Epoch : 477	Train_loss : 0.004467	Valid_loss : 0.004473	Saved
# Epoch : 478	Train_loss : 0.004453	Valid_loss : 0.004472	Saved
# Epoch : 479	Train_loss : 0.004401	Valid_loss : 0.004470	Saved
# Epoch : 480	Train_loss : 0.004481	Valid_loss : 0.004470	Saved
# Epoch : 481	Train_loss : 0.004414	Valid_loss : 0.004468	Saved
# Epoch : 482	Train_loss : 0.004437	Valid_loss : 0.004467	Saved
# Epoch : 483	Train_loss : 0.004445	Valid_loss : 0.004467	Saved
# Epoch : 484	Train_loss : 0.004411	Valid_loss : 0.004465	Saved
# Epoch : 485	Train_loss : 0.004449	Valid_loss : 0.004463	Saved
# Epoch : 486	Train_loss : 0.004434	Valid_loss : 0.004461	Saved
# Epoch : 487	Train_loss : 0.004397	Valid_loss : 0.004462	No Saved
# Epoch : 488	Train_loss : 0.004410	Valid_loss : 0.004462	No Saved
# Epoch : 489	Train_loss : 0.004420	Valid_loss : 0.004461	Saved
# Epoch : 490	Train_loss : 0.004396	Valid_loss : 0.004461	No Saved
# Epoch : 491	Train_loss : 0.004419	Valid_loss : 0.004459	Saved
# Epoch : 492	Train_loss : 0.004376	Valid_loss : 0.004458	Saved
# Epoch : 493	Train_loss : 0.004427	Valid_loss : 0.004457	Saved
# Epoch : 494	Train_loss : 0.004366	Valid_loss : 0.004457	No Saved
# Epoch : 495	Train_loss : 0.004394	Valid_loss : 0.004457	No Saved
# Epoch : 496	Train_loss : 0.004379	Valid_loss : 0.004456	Saved
# Epoch : 497	Train_loss : 0.004418	Valid_loss : 0.004455	Saved
# Epoch : 498	Train_loss : 0.004441	Valid_loss : 0.004454	Saved
# Epoch : 499	Train_loss : 0.004366	Valid_loss : 0.004452	Saved
# Epoch : 500	Train_loss : 0.004380	Valid_loss : 0.004452	Saved

# %%
# =======================================================================================
# valid_test
with tf.Session() as sess:
    saver.restore(sess, config.path_ckpt)
    preds_ = run_session(sess, valid_step, [valid_df_cate, valid_df_cont], config, epoch, mode=3)
    preds_ = np.concatenate(preds_)

pred_args = []
for p_ in preds_:
    start_idx = 0
    pred_arg = []
    for kl in config.cate_lens:
        pred_arg.append(np.argmax(p_[start_idx: start_idx+kl]))
        start_idx += kl
    pred_args.append(pred_arg)

pred_args_np = np.array(pred_args)

val_test_ijv = []
for i, vs in enumerate(config.vaild_test_drop_mask):
    for j, v in enumerate(vs):
        if v:
            val_test_ijv.append([i,j,valid_df_cate.values[i,j]])    

sum_true = 0
for ijv in val_test_ijv:
    i,j,v = ijv
    sum_true+=(pred_args_np[i, j] == v)

val_tst_score = sum_true/len(val_test_ijv)
print("val_tst_score : {:6f}".format(val_tst_score))
# Out:
# INFO:tensorflow:Restoring parameters from .\ckpt\best.ckpt
# INFO:tensorflow:Restoring parameters from .\ckpt\best.ckpt
# val_tst_score : 0.987826

# %% [markdown]
# Epoch : 500	Train_loss : 0.004380	Valid_loss : 0.004452	Saved => 0.987826
